# %% [markdown]
# # Basic face recognizer using pre trained model
#
# Below the is the implementation of a very basic face recognizer which can identify the face of the person showing on a web cam.
# The implementation is inspired by two path breaking papers on facial recognition using deep convoluted neural network, namely FaceNet and DeepFace.
#
# I have used pre trained model Keras-OpenFace which is an open source Keras implementation of the OpenFace (Originally Torch implemented)
#
# The pretrained model that I have used is by Victor Sy Wang's implementation and was loaded using his code: https://github.com/iwantooxxoox/Keras-OpenFace.

# %% [markdown]
# # Import the prerequisite libraries
#
# We will be importing utils.py from https://github.com/iwantooxxoox/Keras-OpenFace/blob/master/utils.py (available with code) which contains utility functions to create the neural network and load the weights assoiated with it.

# %%
from keras.models import Sequential
from keras.layers import Conv2D, ZeroPadding2D, Activation, Input, concatenate
from keras.models import Model
from keras.layers.normalization import BatchNormalization
from keras.layers.pooling import MaxPooling2D, AveragePooling2D
from keras.layers.merge import Concatenate
from keras.layers.core import Lambda, Flatten, Dense
from keras.engine.topology import Layer
from keras import backend as K
import cv2
import os
import numpy as np
from numpy import genfromtxt
import pandas as pd
import tensorflow as tf
from utils import LRN2D
import utils

# %load_ext autoreload
# %autoreload 2

np.set_printoptions(threshold=np.nan)
# %reload_ext autoreload
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Contructing the neural network model
# The model here constructed is based on FaceNet's Inception model.
#
# The implementation of model is available at: https://github.com/iwantooxxoox/Keras-OpenFace

# %%
#call the model creation funtion
import Modelcreation
model = Modelcreation.createmodel()

# %% [markdown]
# # Loading the model with pretrained weights
#
# FaceNet is trained by minimizing the triplet loss. I will be  loading a previously trained model. weights are avaiable at https://github.com/iwantooxxoox/Keras-OpenFace in the "weights" folder which is also provided in this source.
#
# This can take a couple of minutes to execute and depends on the speed of your machine.

# %%
print(model.summary())
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 96, 96, 3)    0
# __________________________________________________________________________________________________
# zero_padding2d_24 (ZeroPadding2 (None, 102, 102, 3)  0           input_2[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 48, 48, 64)   9472        zero_padding2d_24[0][0]
# __________________________________________________________________________________________________
# bn1 (BatchNormalization)        (None, 48, 48, 64)   256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 48, 48, 64)   0           bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_25 (ZeroPadding2 (None, 50, 50, 64)   0           activation_38[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 24, 24, 64)   0           zero_padding2d_25[0][0]
# __________________________________________________________________________________________________
# lrn_1 (Lambda)                  (None, 24, 24, 64)   0           max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2 (Conv2D)                  (None, 24, 24, 64)   4160        lrn_1[0][0]
# __________________________________________________________________________________________________
# bn2 (BatchNormalization)        (None, 24, 24, 64)   256         conv2[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 24, 24, 64)   0           bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_26 (ZeroPadding2 (None, 26, 26, 64)   0           activation_39[0][0]
# __________________________________________________________________________________________________
# conv3 (Conv2D)                  (None, 24, 24, 192)  110784      zero_padding2d_26[0][0]
# __________________________________________________________________________________________________
# bn3 (BatchNormalization)        (None, 24, 24, 192)  768         conv3[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 24, 24, 192)  0           bn3[0][0]
# __________________________________________________________________________________________________
# lrn_2 (Lambda)                  (None, 24, 24, 192)  0           activation_40[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_27 (ZeroPadding2 (None, 26, 26, 192)  0           lrn_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 12, 12, 192)  0           zero_padding2d_27[0][0]
# __________________________________________________________________________________________________
# inception_3a_3x3_conv1 (Conv2D) (None, 12, 12, 96)   18528       max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# inception_3a_5x5_conv1 (Conv2D) (None, 12, 12, 16)   3088        max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# inception_3a_3x3_bn1 (BatchNorm (None, 12, 12, 96)   384         inception_3a_3x3_conv1[0][0]
# __________________________________________________________________________________________________
# inception_3a_5x5_bn1 (BatchNorm (None, 12, 12, 16)   64          inception_3a_5x5_conv1[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 12, 12, 96)   0           inception_3a_3x3_bn1[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 12, 12, 16)   0           inception_3a_5x5_bn1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 5, 5, 192)    0           max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_28 (ZeroPadding2 (None, 14, 14, 96)   0           activation_41[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_29 (ZeroPadding2 (None, 16, 16, 16)   0           activation_43[0][0]
# __________________________________________________________________________________________________
# inception_3a_pool_conv (Conv2D) (None, 5, 5, 32)     6176        max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# inception_3a_3x3_conv2 (Conv2D) (None, 12, 12, 128)  110720      zero_padding2d_28[0][0]
# __________________________________________________________________________________________________
# inception_3a_5x5_conv2 (Conv2D) (None, 12, 12, 32)   12832       zero_padding2d_29[0][0]
# __________________________________________________________________________________________________
# inception_3a_pool_bn (BatchNorm (None, 5, 5, 32)     128         inception_3a_pool_conv[0][0]
# __________________________________________________________________________________________________
# inception_3a_1x1_conv (Conv2D)  (None, 12, 12, 64)   12352       max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# inception_3a_3x3_bn2 (BatchNorm (None, 12, 12, 128)  512         inception_3a_3x3_conv2[0][0]
# __________________________________________________________________________________________________
# inception_3a_5x5_bn2 (BatchNorm (None, 12, 12, 32)   128         inception_3a_5x5_conv2[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 5, 5, 32)     0           inception_3a_pool_bn[0][0]
# __________________________________________________________________________________________________
# inception_3a_1x1_bn (BatchNorma (None, 12, 12, 64)   256         inception_3a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 12, 12, 128)  0           inception_3a_3x3_bn2[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 12, 12, 32)   0           inception_3a_5x5_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_30 (ZeroPadding2 (None, 12, 12, 32)   0           activation_45[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 12, 12, 64)   0           inception_3a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 12, 12, 256)  0           activation_42[0][0]
#                                                                  activation_44[0][0]
#                                                                  zero_padding2d_30[0][0]
#                                                                  activation_46[0][0]
# __________________________________________________________________________________________________
# power2_3b (Lambda)              (None, 12, 12, 256)  0           concatenate_8[0][0]
# __________________________________________________________________________________________________
# inception_3b_3x3_conv1 (Conv2D) (None, 12, 12, 96)   24672       concatenate_8[0][0]
# __________________________________________________________________________________________________
# inception_3b_5x5_conv1 (Conv2D) (None, 12, 12, 32)   8224        concatenate_8[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, 4, 4, 256)    0           power2_3b[0][0]
# __________________________________________________________________________________________________
# inception_3b_3x3_bn1 (BatchNorm (None, 12, 12, 96)   384         inception_3b_3x3_conv1[0][0]
# __________________________________________________________________________________________________
# inception_3b_5x5_bn1 (BatchNorm (None, 12, 12, 32)   128         inception_3b_5x5_conv1[0][0]
# __________________________________________________________________________________________________
# mult9_3b (Lambda)               (None, 4, 4, 256)    0           average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 12, 12, 96)   0           inception_3b_3x3_bn1[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 12, 12, 32)   0           inception_3b_5x5_bn1[0][0]
# __________________________________________________________________________________________________
# sqrt_3b (Lambda)                (None, 4, 4, 256)    0           mult9_3b[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_31 (ZeroPadding2 (None, 14, 14, 96)   0           activation_47[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_32 (ZeroPadding2 (None, 16, 16, 32)   0           activation_49[0][0]
# __________________________________________________________________________________________________
# inception_3b_pool_conv (Conv2D) (None, 4, 4, 64)     16448       sqrt_3b[0][0]
# __________________________________________________________________________________________________
# inception_3b_3x3_conv2 (Conv2D) (None, 12, 12, 128)  110720      zero_padding2d_31[0][0]
# __________________________________________________________________________________________________
# inception_3b_5x5_conv2 (Conv2D) (None, 12, 12, 64)   51264       zero_padding2d_32[0][0]
# __________________________________________________________________________________________________
# inception_3b_pool_bn (BatchNorm (None, 4, 4, 64)     256         inception_3b_pool_conv[0][0]
# __________________________________________________________________________________________________
# inception_3b_1x1_conv (Conv2D)  (None, 12, 12, 64)   16448       concatenate_8[0][0]
# __________________________________________________________________________________________________
# inception_3b_3x3_bn2 (BatchNorm (None, 12, 12, 128)  512         inception_3b_3x3_conv2[0][0]
# __________________________________________________________________________________________________
# inception_3b_5x5_bn2 (BatchNorm (None, 12, 12, 64)   256         inception_3b_5x5_conv2[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 4, 4, 64)     0           inception_3b_pool_bn[0][0]
# __________________________________________________________________________________________________
# inception_3b_1x1_bn (BatchNorma (None, 12, 12, 64)   256         inception_3b_1x1_conv[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 12, 12, 128)  0           inception_3b_3x3_bn2[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 12, 12, 64)   0           inception_3b_5x5_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_33 (ZeroPadding2 (None, 12, 12, 64)   0           activation_51[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 12, 12, 64)   0           inception_3b_1x1_bn[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 12, 12, 320)  0           activation_48[0][0]
#                                                                  activation_50[0][0]
#                                                                  zero_padding2d_33[0][0]
#                                                                  activation_52[0][0]
# __________________________________________________________________________________________________
# inception_3c_3x3_conv1 (Conv2D) (None, 12, 12, 128)  41088       concatenate_9[0][0]
# __________________________________________________________________________________________________
# inception_3c_5x5_conv1 (Conv2D) (None, 12, 12, 32)   10272       concatenate_9[0][0]
# __________________________________________________________________________________________________
# inception_3c_3x3_bn1 (BatchNorm (None, 12, 12, 128)  512         inception_3c_3x3_conv1[0][0]
# __________________________________________________________________________________________________
# inception_3c_5x5_bn1 (BatchNorm (None, 12, 12, 32)   128         inception_3c_5x5_conv1[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 12, 12, 128)  0           inception_3c_3x3_bn1[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 12, 12, 32)   0           inception_3c_5x5_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_34 (ZeroPadding2 (None, 14, 14, 128)  0           activation_53[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_35 (ZeroPadding2 (None, 16, 16, 32)   0           activation_55[0][0]
# __________________________________________________________________________________________________
# inception_3c_3x3_conv2 (Conv2D) (None, 6, 6, 256)    295168      zero_padding2d_34[0][0]
# __________________________________________________________________________________________________
# inception_3c_5x5_conv2 (Conv2D) (None, 6, 6, 64)     51264       zero_padding2d_35[0][0]
# __________________________________________________________________________________________________
# inception_3c_3x3_bn2 (BatchNorm (None, 6, 6, 256)    1024        inception_3c_3x3_conv2[0][0]
# __________________________________________________________________________________________________
# inception_3c_5x5_bn2 (BatchNorm (None, 6, 6, 64)     256         inception_3c_5x5_conv2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 5, 5, 320)    0           concatenate_9[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 6, 6, 256)    0           inception_3c_3x3_bn2[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 6, 6, 64)     0           inception_3c_5x5_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_36 (ZeroPadding2 (None, 6, 6, 320)    0           max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 6, 6, 640)    0           activation_54[0][0]
#                                                                  activation_56[0][0]
#                                                                  zero_padding2d_36[0][0]
# __________________________________________________________________________________________________
# power2_4a (Lambda)              (None, 6, 6, 640)    0           concatenate_10[0][0]
# __________________________________________________________________________________________________
# inception_4a_3x3_conv1 (Conv2D) (None, 6, 6, 96)     61536       concatenate_10[0][0]
# __________________________________________________________________________________________________
# inception_4a_5x5_conv1 (Conv2D) (None, 6, 6, 32)     20512       concatenate_10[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, 2, 2, 640)    0           power2_4a[0][0]
# __________________________________________________________________________________________________
# inception_4a_3x3_bn1 (BatchNorm (None, 6, 6, 96)     384         inception_4a_3x3_conv1[0][0]
# __________________________________________________________________________________________________
# inception_4a_5x5_bn1 (BatchNorm (None, 6, 6, 32)     128         inception_4a_5x5_conv1[0][0]
# __________________________________________________________________________________________________
# mult9_4a (Lambda)               (None, 2, 2, 640)    0           average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 6, 6, 96)     0           inception_4a_3x3_bn1[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 6, 6, 32)     0           inception_4a_5x5_bn1[0][0]
# __________________________________________________________________________________________________
# sqrt_4a (Lambda)                (None, 2, 2, 640)    0           mult9_4a[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_37 (ZeroPadding2 (None, 8, 8, 96)     0           activation_57[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_38 (ZeroPadding2 (None, 10, 10, 32)   0           activation_59[0][0]
# __________________________________________________________________________________________________
# inception_4a_pool_conv (Conv2D) (None, 2, 2, 128)    82048       sqrt_4a[0][0]
# __________________________________________________________________________________________________
# inception_4a_3x3_conv2 (Conv2D) (None, 6, 6, 192)    166080      zero_padding2d_37[0][0]
# __________________________________________________________________________________________________
# inception_4a_5x5_conv2 (Conv2D) (None, 6, 6, 64)     51264       zero_padding2d_38[0][0]
# __________________________________________________________________________________________________
# inception_4a_pool_bn (BatchNorm (None, 2, 2, 128)    512         inception_4a_pool_conv[0][0]
# __________________________________________________________________________________________________
# inception_4a_1x1_conv (Conv2D)  (None, 6, 6, 256)    164096      concatenate_10[0][0]
# __________________________________________________________________________________________________
# inception_4a_3x3_bn2 (BatchNorm (None, 6, 6, 192)    768         inception_4a_3x3_conv2[0][0]
# __________________________________________________________________________________________________
# inception_4a_5x5_bn2 (BatchNorm (None, 6, 6, 64)     256         inception_4a_5x5_conv2[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 2, 2, 128)    0           inception_4a_pool_bn[0][0]
# __________________________________________________________________________________________________
# inception_4a_1x1_bn (BatchNorma (None, 6, 6, 256)    1024        inception_4a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 6, 6, 192)    0           inception_4a_3x3_bn2[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 6, 6, 64)     0           inception_4a_5x5_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_39 (ZeroPadding2 (None, 6, 6, 128)    0           activation_61[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 6, 6, 256)    0           inception_4a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 6, 6, 640)    0           activation_58[0][0]
#                                                                  activation_60[0][0]
#                                                                  zero_padding2d_39[0][0]
#                                                                  activation_62[0][0]
# __________________________________________________________________________________________________
# inception_4e_3x3_conv1 (Conv2D) (None, 6, 6, 160)    102560      concatenate_11[0][0]
# __________________________________________________________________________________________________
# inception_4e_5x5_conv1 (Conv2D) (None, 6, 6, 64)     41024       concatenate_11[0][0]
# __________________________________________________________________________________________________
# inception_4e_3x3_bn1 (BatchNorm (None, 6, 6, 160)    640         inception_4e_3x3_conv1[0][0]
# __________________________________________________________________________________________________
# inception_4e_5x5_bn1 (BatchNorm (None, 6, 6, 64)     256         inception_4e_5x5_conv1[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 6, 6, 160)    0           inception_4e_3x3_bn1[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 6, 6, 64)     0           inception_4e_5x5_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_40 (ZeroPadding2 (None, 8, 8, 160)    0           activation_63[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_41 (ZeroPadding2 (None, 10, 10, 64)   0           activation_65[0][0]
# __________________________________________________________________________________________________
# inception_4e_3x3_conv2 (Conv2D) (None, 3, 3, 256)    368896      zero_padding2d_40[0][0]
# __________________________________________________________________________________________________
# inception_4e_5x5_conv2 (Conv2D) (None, 3, 3, 128)    204928      zero_padding2d_41[0][0]
# __________________________________________________________________________________________________
# inception_4e_3x3_bn2 (BatchNorm (None, 3, 3, 256)    1024        inception_4e_3x3_conv2[0][0]
# __________________________________________________________________________________________________
# inception_4e_5x5_bn2 (BatchNorm (None, 3, 3, 128)    512         inception_4e_5x5_conv2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 2, 2, 640)    0           concatenate_11[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 3, 3, 256)    0           inception_4e_3x3_bn2[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 3, 3, 128)    0           inception_4e_5x5_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_42 (ZeroPadding2 (None, 3, 3, 640)    0           max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 3, 3, 1024)   0           activation_64[0][0]
#                                                                  activation_66[0][0]
#                                                                  zero_padding2d_42[0][0]
# __________________________________________________________________________________________________
# power2_5a (Lambda)              (None, 3, 3, 1024)   0           concatenate_12[0][0]
# __________________________________________________________________________________________________
# inception_5a_3x3_conv1 (Conv2D) (None, 3, 3, 96)     98400       concatenate_12[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_7 (AveragePoo (None, 1, 1, 1024)   0           power2_5a[0][0]
# __________________________________________________________________________________________________
# inception_5a_3x3_bn1 (BatchNorm (None, 3, 3, 96)     384         inception_5a_3x3_conv1[0][0]
# __________________________________________________________________________________________________
# mult9_5a (Lambda)               (None, 1, 1, 1024)   0           average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 3, 3, 96)     0           inception_5a_3x3_bn1[0][0]
# __________________________________________________________________________________________________
# sqrt_5a (Lambda)                (None, 1, 1, 1024)   0           mult9_5a[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_43 (ZeroPadding2 (None, 5, 5, 96)     0           activation_67[0][0]
# __________________________________________________________________________________________________
# inception_5a_pool_conv (Conv2D) (None, 1, 1, 96)     98400       sqrt_5a[0][0]
# __________________________________________________________________________________________________
# inception_5a_3x3_conv2 (Conv2D) (None, 3, 3, 384)    332160      zero_padding2d_43[0][0]
# __________________________________________________________________________________________________
# inception_5a_pool_bn (BatchNorm (None, 1, 1, 96)     384         inception_5a_pool_conv[0][0]
# __________________________________________________________________________________________________
# inception_5a_1x1_conv (Conv2D)  (None, 3, 3, 256)    262400      concatenate_12[0][0]
# __________________________________________________________________________________________________
# inception_5a_3x3_bn2 (BatchNorm (None, 3, 3, 384)    1536        inception_5a_3x3_conv2[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 1, 1, 96)     0           inception_5a_pool_bn[0][0]
# __________________________________________________________________________________________________
# inception_5a_1x1_bn (BatchNorma (None, 3, 3, 256)    1024        inception_5a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 3, 3, 384)    0           inception_5a_3x3_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_44 (ZeroPadding2 (None, 3, 3, 96)     0           activation_69[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 3, 3, 256)    0           inception_5a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 3, 3, 736)    0           activation_68[0][0]
#                                                                  zero_padding2d_44[0][0]
#                                                                  activation_70[0][0]
# __________________________________________________________________________________________________
# inception_5b_3x3_conv1 (Conv2D) (None, 3, 3, 96)     70752       concatenate_13[0][0]
# __________________________________________________________________________________________________
# inception_5b_3x3_bn1 (BatchNorm (None, 3, 3, 96)     384         inception_5b_3x3_conv1[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 3, 3, 96)     0           inception_5b_3x3_bn1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 1, 1, 736)    0           concatenate_13[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_45 (ZeroPadding2 (None, 5, 5, 96)     0           activation_71[0][0]
# __________________________________________________________________________________________________
# inception_5b_pool_conv (Conv2D) (None, 1, 1, 96)     70752       max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# inception_5b_3x3_conv2 (Conv2D) (None, 3, 3, 384)    332160      zero_padding2d_45[0][0]
# __________________________________________________________________________________________________
# inception_5b_pool_bn (BatchNorm (None, 1, 1, 96)     384         inception_5b_pool_conv[0][0]
# __________________________________________________________________________________________________
# inception_5b_1x1_conv (Conv2D)  (None, 3, 3, 256)    188672      concatenate_13[0][0]
# __________________________________________________________________________________________________
# inception_5b_3x3_bn2 (BatchNorm (None, 3, 3, 384)    1536        inception_5b_3x3_conv2[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 1, 1, 96)     0           inception_5b_pool_bn[0][0]
# __________________________________________________________________________________________________
# inception_5b_1x1_bn (BatchNorma (None, 3, 3, 256)    1024        inception_5b_1x1_conv[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 3, 3, 384)    0           inception_5b_3x3_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_46 (ZeroPadding2 (None, 3, 3, 96)     0           activation_73[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 3, 3, 256)    0           inception_5b_1x1_bn[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 3, 3, 736)    0           activation_72[0][0]
#                                                                  zero_padding2d_46[0][0]
#                                                                  activation_74[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_8 (AveragePoo (None, 1, 1, 736)    0           concatenate_14[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 736)          0           average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# dense_layer (Dense)             (None, 128)          94336       flatten_2[0][0]
# __________________________________________________________________________________________________
# norm_layer (Lambda)             (None, 128)          0           dense_layer[0][0]
# ==================================================================================================
# Total params: 3,743,280
# Trainable params: 3,733,968
# Non-trainable params: 9,312
# __________________________________________________________________________________________________
# None

# %%
# Load weights from csv files (which was exported from Openface torch model)
weights = utils.weights
weights_dict = utils.load_weights()

# %%
# Set layer weights of the model
for name in weights:
    if model.get_layer(name) != None:
        model.get_layer(name).set_weights(weights_dict[name])
    elif model.get_layer(name) != None:
        model.get_layer(name).set_weights(weights_dict[name])

# %% [markdown]
# ## About <font color=blue>image_to_embedding</font> function
# When the model is loaded with pre trained weights, then we can create the **128 dimensional embedding vectors** for all the face images stored in the "images" folder. **"image_to_embedding"** function pass an image to the Inception network to generate the embedding vector.

# %%
def image_to_embedding(image, model):
    #image = cv2.resize(image, (96, 96), interpolation=cv2.INTER_AREA) 
    image = cv2.resize(image, (96, 96)) 
    img = image[...,::-1]
    img = np.around(np.transpose(img, (0,1,2))/255.0, decimals=12)
    x_train = np.array([img])
    embedding = model.predict_on_batch(x_train)
    return embedding

# %% [markdown]
# ## About <font color=blue>recognize_face</font> function
# This function calculate similarity between the captured image and the images that are already been stored. It passes the image to the trained neural network to generate its embedding vector. Which is then compared with all the embedding vectors of the images stored by calculating L2 Euclidean distance.
#
# If the minimum L2 distance between two embeddings is less than a threshpld (here I have taken the threashhold as .68 (which can be adjusted) then we have a match.

# %%
def recognize_face(face_image, input_embeddings, model):

    embedding = image_to_embedding(face_image, model)
    
    minimum_distance = 200
    name = None
    
    # Loop over  names and encodings.
    for (input_nam      cv2.imshow("Face Recognizer", img)

        if key == 27: # exit on ESC
            break
    vc.release()
    cv2.destroyAllWindows()e, input_embedding) in input_embeddings.items():
        
       
        euclidean_distance = np.linalg.norm(embedding-input_embedding)
        

        print('Euclidean distance from %s is %s' %(input_name, euclidean_distance))

        
        if euclidean_distance < minimum_distance:
            minimum_distance = euclidean_distance
            name = input_name
    
    if minimum_distance < 0.68:
        return str(name)
    else:
        return None

# %% [markdown]
# ## About <font color=blue>create_input_image_embeddings</font> function
# This function generates 128 dimensional image ebeddings of all the images stored in the "images" directory by feed forwarding the images to a trained neural network. It creates a dictionary with key as the name of the face and value as embedding
#
#
# ## About <font color=blue>recognize_faces_in_cam</font> function
# This function capture image from the webcam, detect a face in it and crop the image to have a face only, which is then passed to recognize_face function.

# %%
import glob

def create_input_image_embeddings():
    input_embeddings = {}

    for file in glob.glob("images/*"):
        person_name = os.path.splitext(os.path.basename(file))[0]
        image_file = cv2.imread(file, 1)
        input_embeddings[person_name] = ima 'img' is not definedge_to_embedding(image_file, model)
    return input_embeddings

def recognize_faces_in_cam(input_embeddings):
    cv2.namedWindow("Face Recognizer")
    #vc = cv2.VideoCapture(0)
    vc=cv2.VideoCapture('/home/vishnu/Desktop/video1.mp4')
    font = cv2.FONT_HERSHEY_SIMPLEX
    face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml') 
    while vc.isOpened():
        _, rframe  = vc.read()
        frame = cv2.resize(rframe, (640, 480)) 
        img =frame
        height, width, channels = frame.shape
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        faces = face_cascade.detectMultiScale(gray, 1.3, 5)
        # Loop through all the faces detected 
        identities = []
        for (x, y, w, h) in faces:
            x1 = x
            y1 = y
            x2 = x+w
            y2 = y+h
            face_image = frame[max(0, y1):min(height, y2), max(0, x1):min(width, x2)]    
            identity = recognize_face(face_ 'img' is not definedimage, input_embeddings, model)
            if identity is not None:
                img = cv2.rectangle(frame,(x1, y1),(x2, y2),(255,255,255),2)
                cv2.putText(img, str(identity), (x1+5,y1-5), font, 1, (255,255,255), 2)
        key = cv2.waitKey(100)
        cv2.imshow("Face Recognizer", img)
        if key == 27: # exit on ESC
            break
    vc.release()
    cv2.destroyAllWindows()

# %% [markdown]
# Capturing the face image
# Following code captures 10 face images of the person. They all are stored in **"images"** folder with the name User_1 to User_10. Select a good captured image from the set of 10 images. Rename it with the name of person and delete rest of them. This image will be used for recognizing the the identity of the person using one shot learning.

# %%
import sqlite3
import cv2
import numpy as np

cam = cv2.VideoCapture(0)
#cam = cv2.VideoCapture('http://172.16.2.167:8080/video') #taking the image through the webcam

try:
    face_detector = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
    def insertOrUpdate(Id,Name,Regno):
        conn = sqlite3.connect("Container.db")
        cmd = "SELECT * FROM Identity WHERE ID="+str(Id)
        cursor = conn.execute(cmd)
        isRecordExist = 0
        for row in cursor:
            isRecordExist=1 
        if(isRecordExist==1):
            cmd = "UPDATE Identity SET Name=' "+str(Name)+" ' WHERE ID="+str(Id)
            cmd = "UPDATE Identity SET Regno=' "+str(Regno)+" ' WHERE ID="+str(Id)
        else:
            cmd ="INSERT INTO Identity(ID,Name,Regno) Values("+str(Id)+",' "+str(Name)+" ',' "+str(Regno)+" ')"  
        conn.execute(cmd)
        conn.commit()
        conn.close()

    Id = input("enter your id : ")
    name = input("Enter Your Name : ")
    reg =input("Enter Your Registration Number : ")

    insertOrUpdate(Id, name,reg)


    count = 0
    while(True):
        ret, frame = cam.read()
        img = cv2.resize(frame, (640, 480)) 
        #gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        #general Intuition to detect the faces.

        faces = face_detector.detectMultiScale(img, 1.3, 5)
        for (x,y,w,h) in faces:
            x1 = x
            y1 = y
            x2 = x+w
            y2 = y+h
            cv2.rectangle(img, (x1,y1), (x2,y2), (255,255,255), 2)     
            count += 1
            # Save the captured image into the datasets folder
            #cv2.imwrite("images/User_" + str(count) + ".jpg", img[y1:y2,x1:x2])
            cv2.imwrite("images/" +  name  +"." +str(Id )+'.'+ str(count) + ".jpg", img[y1:y2,x1:x2])
            cv2.imshow('image+window', img)
            cv2.namedWindow("image_window", cv2.WINDOW_NORMAL)
        k = cv2.waitKey(200) & 0xff # Press 'ESC' for exiting video to terminate the webcam.
        if k == 27:
            break
        elif count >= 10: # Take 30 face sample and stop video
             break
    cam.release()
    cv2.destroyAllWindows()
    
except Exception as e:
    #to destroy the camera
    print('The Error is : ',str(e))
    cam.release()
    cv2.destroyAllWindows()
# Out:
# enter your id : 12
# Enter Your Name : priyansh
# Enter Your Registration Number : 457

# %% [markdown]
# # Lets run the face recognizer program :-)

# %%
input_embeddings = create_input_image_embeddings()
recognize_faces_in_cam(input_embeddings)
# Out:
# Euclidean distance from priyansh.12.1 is 1.2273353
# Euclidean distance from none.1.1 is 0.93733865
# Euclidean distance from priyansh.12.1 is 0.869877
# Euclidean distance from none.1.1 is 1.024006
# Euclidean distance from priyansh.12.1 is 1.1691378
# Euclidean distance from none.1.1 is 1.2063586
# Euclidean distance from priyansh.12.1 is 1.1369828
# Euclidean distance from none.1.1 is 1.0331635
# Euclidean distance from priyansh.12.1 is 0.9929765
# Euclidean distance from none.1.1 is 0.93774146
# Euclidean distance from priyansh.12.1 is 1.0980546
# Euclidean distance from none.1.1 is 0.9336938
# Euclidean distance from priyansh.12.1 is 0.87793183
# Euclidean distance from none.1.1 is 0.9887166
# Euclidean distance from priyansh.12.1 is 0.867958
# Euclidean distance from none.1.1 is 1.0510964
# Euclidean distance from priyansh.12.1 is 1.2429368
# Euclidean distance from none.1.1 is 0.9364335
# Euclidean distance from priyansh.12.1 is 1.2328023
# Euclidean distance from none.1.1 is 0.865603
# Euclidean distance from priyansh.12.1 is 1.0313723
# Euclidean distance from none.1.1 is 0.96835357
# Euclidean distance from priyansh.12.1 is 0.9694111
# Euclidean distance from none.1.1 is 1.0314236
# Euclidean distance from priyansh.12.1 is 1.1469536
# Euclidean distance from none.1.1 is 0.9042238
# Euclidean distance from priyansh.12.1 is 1.0663186
# Euclidean distance from none.1.1 is 0.90368646
# Euclidean distance from priyansh.12.1 is 0.8211381
# Euclidean distance from none.1.1 is 1.1695206
# Euclidean distance from priyansh.12.1 is 0.90650046
# Euclidean distance from none.1.1 is 1.0135353
# Euclidean distance from priyansh.12.1 is 0.8367399
# Euclidean distance from none.1.1 is 1.0720534
# Euclidean distance from priyansh.12.1 is 0.8421717
# Euclidean distance from none.1.1 is 1.1410662
# Euclidean distance from priyansh.12.1 is 0.9780296
# Euclidean distance from none.1.1 is 1.000828
# Euclidean distance from priyansh.12.1 is 0.8254127
# Euclidean distance from none.1.1 is 1.0767244
# Euclidean distance from priyansh.12.1 is 0.8146077
# Euclidean distance from none.1.1 is 1.1340632
# Euclidean distance from priyansh.12.1 is 1.0019971
# Euclidean distance from none.1.1 is 0.95453537
# Euclidean distance from priyansh.12.1 is 0.9364594
# Euclidean distance from none.1.1 is 0.94104505
# Euclidean distance from priyansh.12.1 is 1.1154379
# Euclidean distance from none.1.1 is 0.88053113
# Euclidean distance from priyansh.12.1 is 0.83873117
# Euclidean distance from none.1.1 is 1.1038458
# Euclidean distance from priyansh.12.1 is 0.79532593
# Euclidean distance from none.1.1 is 1.0330132
# Euclidean distance from priyansh.12.1 is 0.88537705
# Euclidean distance from none.1.1 is 1.0698891
# Euclidean distance from priyansh.12.1 is 0.79710597
# Euclidean distance from none.1.1 is 1.1030087
# Euclidean distance from priyansh.12.1 is 0.9163392
# Euclidean distance from none.1.1 is 1.2142556
# Euclidean distance from priyansh.12.1 is 0.8714254
# Euclidean distance from none.1.1 is 1.2629427
# Euclidean distance from priyansh.12.1 is 0.8572096
# Euclidean distance from none.1.1 is 1.0962403
# Euclidean distance from priyansh.12.1 is 0.83675736
# Euclidean distance from none.1.1 is 1.0373558
# Euclidean distance from priyansh.12.1 is 0.7662358
# Euclidean distance from none.1.1 is 1.1302371
# Euclidean distance from priyansh.12.1 is 0.758198
# Euclidean distance from none.1.1 is 1.0804226
# Euclidean distance from priyansh.12.1 is 0.8777397
# Euclidean distance from none.1.1 is 1.0651388
# Euclidean distance from priyansh.12.1 is 0.9456271
# Euclidean distance from none.1.1 is 0.99698746
# Euclidean distance from priyansh.12.1 is 0.73822474
# Euclidean distance from none.1.1 is 1.1399086
# Euclidean distance from priyansh.12.1 is 0.80013734
# Euclidean distance from none.1.1 is 1.1107643
# Euclidean distance from priyansh.12.1 is 1.0913309
# Euclidean distance from none.1.1 is 0.9699845
# Euclidean distance from priyansh.12.1 is 0.67063475
# Euclidean distance from none.1.1 is 1.1152724
# Euclidean distance from priyansh.12.1 is 0.84562856
# Euclidean distance from none.1.1 is 1.042582
# Euclidean distance from priyansh.12.1 is 1.0229939
# Euclidean distance from none.1.1 is 0.95612264
# Euclidean distance from priyansh.12.1 is 0.77487457
# Euclidean distance from none.1.1 is 1.1831702
# Euclidean distance from priyansh.12.1 is 0.824719
# Euclidean distance from none.1.1 is 1.0907097
# Euclidean distance from priyansh.12.1 is 0.7869463
# Euclidean distance from none.1.1 is 1.1021498
# Euclidean distance from priyansh.12.1 is 0.8139353
# Euclidean distance from none.1.1 is 1.0163008
# Euclidean distance from priyansh.12.1 is 0.871239
# Euclidean distance from none.1.1 is 0.9999432
# Euclidean distance from priyansh.12.1 is 0.7647449
# Euclidean distance from none.1.1 is 1.0890855
# Euclidean distance from priyansh.12.1 is 0.8466693
# Euclidean distance from none.1.1 is 1.0980321
# Euclidean distance from priyansh.12.1 is 1.0427903
# Euclidean distance from none.1.1 is 0.9607142
# Euclidean distance from priyansh.12.1 is 0.8234038
# Euclidean distance from none.1.1 is 1.0432198
# Euclidean distance from priyansh.12.1 is 0.9186123
# Euclidean distance from none.1.1 is 0.97768223
# Euclidean distance from priyansh.12.1 is 0.9510534
# Euclidean distance from none.1.1 is 0.9439806
# Euclidean distance from priyansh.12.1 is 0.9018255
# Euclidean distance from none.1.1 is 0.9446171
# Euclidean distance from priyansh.12.1 is 0.9595313
# Euclidean distance from none.1.1 is 0.9684006
# Euclidean distance from priyansh.12.1 is 1.0240234
# Euclidean distance from none.1.1 is 0.8180858
# Euclidean distance from priyansh.12.1 is 0.8836948
# Euclidean distance from none.1.1 is 0.9398464
# Euclidean distance from priyansh.12.1 is 0.9846183
# Euclidean distance from none.1.1 is 0.98789024
# Euclidean distance from priyansh.12.1 is 0.9378344
# Euclidean distance from none.1.1 is 0.9376105
# Euclidean distance from priyansh.12.1 is 0.7221594
# Euclidean distance from none.1.1 is 1.108912
# Euclidean distance from priyansh.12.1 is 0.61569875
# Euclidean distance from none.1.1 is 1.167141
# Euclidean distance from priyansh.12.1 is 0.8558607
# Euclidean distance from none.1.1 is 0.8358852
# Euclidean distance from priyansh.12.1 is 0.7931558
# Euclidean distance from none.1.1 is 1.0721881
# Euclidean distance from priyansh.12.1 is 0.7791067
# Euclidean distance from none.1.1 is 1.038355
# Euclidean distance from priyansh.12.1 is 0.71983093
# Euclidean distance from none.1.1 is 1.1562086
# Euclidean distance from priyansh.12.1 is 0.75546217
# Euclidean distance from none.1.1 is 1.0484428
# Euclidean distance from priyansh.12.1 is 0.9070127
# Euclidean distance from none.1.1 is 1.001742
# Euclidean distance from priyansh.12.1 is 0.73758197
# Euclidean distance from none.1.1 is 1.0782492
# Euclidean distance from priyansh.12.1 is 0.9032723
# Euclidean distance from none.1.1 is 0.90325135
# Euclidean distance from priyansh.12.1 is 0.79388195
# Euclidean distance from none.1.1 is 1.1564003
# Euclidean distance from priyansh.12.1 is 0.83574337
# Euclidean distance from none.1.1 is 1.0237024
# Euclidean distance from priyansh.12.1 is 0.7495751
# Euclidean distance from none.1.1 is 1.1053268
# Euclidean distance from priyansh.12.1 is 0.7432718
# Euclidean distance from none.1.1 is 1.0438888
# Euclidean distance from priyansh.12.1 is 0.69081014
# Euclidean distance from none.1.1 is 1.1505374
# Euclidean distance from priyansh.12.1 is 0.6790221
# Euclidean distance from none.1.1 is 1.0903726
# Euclidean distance from priyansh.12.1 is 0.84449136
# Euclidean distance from none.1.1 is 1.0188574
# Euclidean distance from priyansh.12.1 is 0.8512361
# Euclidean distance from none.1.1 is 1.1272509
# Euclidean distance from priyansh.12.1 is 1.0033286
# Euclidean distance from none.1.1 is 0.97338796
# Euclidean distance from priyansh.12.1 is 0.7884244
# Euclidean distance from none.1.1 is 1.0235492
# Euclidean distance from priyansh.12.1 is 1.0536696
# Euclidean distance from none.1.1 is 0.9624124
# Euclidean distance from priyansh.12.1 is 0.76092744
# Euclidean distance from none.1.1 is 0.9418919
# Euclidean distance from priyansh.12.1 is 0.604843
# Euclidean distance from none.1.1 is 1.1535572
# Euclidean distance from priyansh.12.1 is 0.68522215
# Euclidean distance from none.1.1 is 1.1760398
# Euclidean distance from priyansh.12.1 is 0.7636771
# Euclidean distance from none.1.1 is 1.0331151
# Euclidean distance from priyansh.12.1 is 0.71031195
# Euclidean distance from none.1.1 is 1.0278329
# Euclidean distance from priyansh.12.1 is 0.6994298
# Euclidean distance from none.1.1 is 1.0697744
# Euclidean distance from priyansh.12.1 is 0.75861365
# Euclidean distance from none.1.1 is 1.0801263
# Euclidean distance from priyansh.12.1 is 0.77210504
# Euclidean distance from none.1.1 is 0.9577399
# Euclidean distance from priyansh.12.1 is 0.87534773
# Euclidean distance from none.1.1 is 0.8981014
# Euclidean distance from priyansh.12.1 is 0.9600687
# Euclidean distance from none.1.1 is 0.81396526
# Euclidean distance from priyansh.12.1 is 0.8392991
# Euclidean distance from none.1.1 is 0.9068199
# Euclidean distance from priyansh.12.1 is 0.78259116
# Euclidean distance from none.1.1 is 1.0304602
# Euclidean distance from priyansh.12.1 is 0.89365566
# Euclidean distance from none.1.1 is 1.0089434
# Euclidean distance from priyansh.12.1 is 0.89346457
# Euclidean distance from none.1.1 is 1.0273873
# Euclidean distance from priyansh.12.1 is 0.99427545
# Euclidean distance from none.1.1 is 1.0255468
# Euclidean distance from priyansh.12.1 is 0.8167916
# Euclidean distance from none.1.1 is 1.1499624
# Euclidean distance from priyansh.12.1 is 0.88169885
# Euclidean distance from none.1.1 is 1.1023788
# Euclidean distance from priyansh.12.1 is 0.66995853
# Euclidean distance from none.1.1 is 1.1947911
# Euclidean distance from priyansh.12.1 is 0.74746084
# Euclidean distance from none.1.1 is 1.1427319
# Euclidean distance from priyansh.12.1 is 1.2061305
# Euclidean distance from none.1.1 is 0.99056923
# Euclidean distance from priyansh.12.1 is 1.2520291
# Euclidean distance from none.1.1 is 1.0398917
# Euclidean distance from priyansh.12.1 is 1.0762693
# Euclidean distance from none.1.1 is 0.9416084
# Euclidean distance from priyansh.12.1 is 0.84545046
# Euclidean distance from none.1.1 is 1.0348504
# Euclidean distance from priyansh.12.1 is 0.94698066
# Euclidean distance from none.1.1 is 1.0248926
# Euclidean distance from priyansh.12.1 is 0.98275864
# Euclidean distance from none.1.1 is 1.0193566
# Euclidean distance from priyansh.12.1 is 0.7815188
# Euclidean distance from none.1.1 is 1.0788288
# Euclidean distance from priyansh.12.1 is 1.0000858
# Euclidean distance from none.1.1 is 0.9323412
# Euclidean distance from priyansh.12.1 is 0.6237281
# Euclidean distance from none.1.1 is 1.0822282
# Euclidean distance from priyansh.12.1 is 0.9678427
# Euclidean distance from none.1.1 is 1.0247556
# Euclidean distance from priyansh.12.1 is 1.0894997
# Euclidean distance from none.1.1 is 0.8948724
# Euclidean distance from priyansh.12.1 is 0.6818414
# Euclidean distance from none.1.1 is 1.1005256
# Euclidean distance from priyansh.12.1 is 0.9389388
# Euclidean distance from none.1.1 is 1.0196222
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-20-c40bafb02c88> in <module>()
#       1 input_embeddings = create_input_image_embeddings()
# ----> 2 recognize_faces_in_cam(input_embeddings)
#
# <ipython-input-9-8b1744542707> in recognize_faces_in_cam(input_embeddings)
#      18     while vc.isOpened():
#      19         _, rframe  = vc.read()
# ---> 20         frame = cv2.resize(rframe, (640, 480))
#      21         img =frame
#      22         height, width, channels = frame.shape
#
# error: OpenCV(4.1.0) /io/opencv/modules/imgproc/src/resize.cpp:3718: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
